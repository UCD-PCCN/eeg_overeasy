# %%
# Load packages
import eeg_pwr
import os
import time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d027c9d9b1fb> in <module>()
#       1 # Load packages
# ----> 2 import eeg_pwr
#       3 import os
#       4 import time
#
# ~/Dropbox (Personal)/Work/Classes/2018 Spring/Python/FinalProject/eeg_overeasy/eeg_pwr.py in <module>()
#     207             return np.array([getattr(np, k)(self.boot_store, -1) for k in stats])
#     208
# --> 209 class boots:
#     210     def __init__(self, fileDir=None,  dataType=None, montage=None, eventMap=None):
#     211
#
# ~/Dropbox (Personal)/Work/Classes/2018 Spring/Python/FinalProject/eeg_overeasy/eeg_pwr.py in boots()
#     316
#     317
# --> 318     def plot_quality_topo(self, montage=montage.pos[:,[0, 1]]):
#     319
#     320         data_avg=self.get_error(across='subjects', type='mean')
#
# NameError: name 'montage' is not defined

# %%
direct='/Users/s/Dropbox (Personal)/Work/Classes/2018 Spring/Python/FinalProject/data'
mont=os.path.join(direct, 'BP64_acti_64rows.sfp')

#event mappings for the test data
evMaps={'1': 1, '2': 2, '3': 3, '48': 48, '77': 77, '88':88, '100': 100, '200' : 200}

# %%
#Access SE estimate for each subject for each electrode
dats.plot_boots(data='boot_SE', data_key='electrode', col_wrap=5, figureSize=(20, 20), cols='Blues',
                  title=3, save=False)

# %%
#Access mean SE for each electrode\
dats.get_error(across='subject', type='mean')

# %%
#Access error SD
dats.get_error(across='subject', type='std')
